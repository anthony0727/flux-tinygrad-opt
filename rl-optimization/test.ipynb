# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from env import CompilerOptEnv
from tinygrad import Device
from tinygrad.device import Compiled
from tinygrad import Device
from pprint import pprint
from tinygrad_utils import get_sched_resnet
env = CompilerOptEnv(
    get_sched_resnet()
)
obs, _ = env.reset()
pprint(obs)
print(obs['graph'].nodes.shape)
from models import GraphUOpsEncoder
# model = GraphUOpsEncoder(768, 256)
# model(obs['graph'].nodes, obs['graph'].edge_links)
from models import CustomCombinedExtractor
# combined = CustomCombinedExtractor(env.obs_space).to('cuda')
from stable_baselines3 import PPO


policy_kwargs = dict(
    features_extractor_class=CustomCombinedExtractor,
    # features_extractor_kwargs=dict(features_dim=128),
)
model = PPO("MultiInputPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
model.learn(1000)
# Out:
# optimizing for <tinygrad.runtime.ops_nv.NVDevice object at 0x79b6389b5a20>
# {'graph': GraphInstance(nodes=tensor([[-0.0007,  0.0072, -0.0407,  ..., -0.0131,  0.0829, -0.0377],
#         [-0.0591, -0.0578,  0.0097,  ..., -0.0131,  0.0829, -0.0377],
#         [-0.0282, -0.0392,  0.0308,  ..., -0.0131,  0.0829, -0.0377],
#         ...,
#         [-0.0273,  0.0601,  0.0130,  ..., -0.0104,  0.0561, -0.0267],
#         [ 0.0395,  0.0334, -0.0622,  ..., -0.0104,  0.0561, -0.0267],
#         [-0.0312,  0.0590, -0.0616,  ...,  0.0551,  0.0730, -0.0540]],
#        device='cuda:0'), edges=None, edge_links=tensor([[ 0,  1,  2,  3,  4,  4,  4,  4,  5,  5,  6,  6,  6,  7,  7,  7,  8,  9,
#           9, 10, 11, 11, 11, 12, 13, 13, 13, 14, 15, 16, 16, 17, 18, 19, 20, 21,
#          22, 22, 23, 23, 24, 24, 25, 26, 27, 28, 29, 30, 30, 30, 30, 31, 32, 33,
#          34, 35, 36, 36, 36, 37, 38, 39, 40, 40, 41, 41, 41, 42, 42, 42, 42, 42,
# ...

# %%
from stable_baselines3 import PPO


policy_kwargs = dict(
    features_extractor_class=CustomCombinedExtractor,
    # features_extractor_kwargs=dict(features_dim=128),
)
model = PPO("MultiInputPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
model.learn(1000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       1 from stable_baselines3 import PPO
#       4 policy_kwargs = dict(
#       5     features_extractor_class=CustomCombinedExtractor,
#       6     # features_extractor_kwargs=dict(features_dim=128),
#       7 )
# ----> 8 model = PPO("MultiInputPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
#       9 model.learn(1000)
#
# ...
